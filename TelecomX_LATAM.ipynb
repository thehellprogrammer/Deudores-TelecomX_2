# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'

# %%
datos_TelecomX = pd.read_json(url)

# %%
original = datos_TelecomX
original.info()
columna_extraida = original['Churn']
print(columna_extraida)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %% [markdown]
# #🔧 Transformación

# %%
customer = pd.json_normalize(datos_TelecomX['customer'])

# %%
print(customer)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
phone = pd.json_normalize(datos_TelecomX['phone'])

# %%
internet = pd.json_normalize(datos_TelecomX['internet'])

# %%
account = pd.json_normalize(datos_TelecomX['account'])

# %%
Unido = pd.concat([columna_extraida ,customer, phone, internet, account], axis=1)
mapeo = {'SI': 1, 'NO': 0}
Unido = Unido.replace( mapeo)

Rotacion =Unido[Unido['Churn'] == 'Yes']
NoRotacion =Unido[Unido['Churn'] == 'No']
#Unido_female = Unido[Unido['gender'] == 'Female']
#Unido_Male = Unido[Unido['gender'] == 'Male']
Rotacion.info()
NoRotacion.info()
print(customer)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1869 entries, 2 to 7263
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Churn             1869 non-null   object
#  1   gender            1869 non-null   object
#  2   SeniorCitizen     1869 non-null   int64
#  3   Partner           1869 non-null   object
#  4   Dependents        1869 non-null   object
#  5   tenure            1869 non-null   int64
#  6   PhoneService      1869 non-null   object
#  7   MultipleLines     1869 non-null   object
#  8   InternetService   1869 non-null   object
#  9   OnlineSecurity    1869 non-null   object
#  10  OnlineBackup      1869 non-null   object
#  11  DeviceProtection  1869 non-null   object
#  12  TechSupport       1869 non-null   object
#  13  StreamingTV       1869 non-null   object
#  14  StreamingMovies   1869 non-null   object
#  15  Contract          1869 non-null   object
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
px.pie(Rotacion, names='gender', title='Distribución de Género, clientes rotativos')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(Rotacion, names='PaymentMethod', title='Metodo de pago de clientes Rotativos')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(NoRotacion, names='PaymentMethod', title='metodo de pago de clientes sin rotación')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(Rotacion, x="tenure",text_auto=True,title='Rotación de clientes según el tiempo con el servicio',)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(Rotacion, x="Contract",text_auto=True,title='Tipo de contrato usado, clientes rotativos',)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Visualizar la distribución de 'Charges.Total' para clientes con y sin evasión usando un gráfico de bigotes
fig_total_charges = px.box(Unido, x="Churn", y="Charges.Total", title="Distribución de 'Total Gastado' para clientes con y sin evasión")
fig_total_charges.show()

# Visualizar la distribución de 'tenure' para clientes con y sin evasión usando un gráfico de bigotes
fig_tenure = px.box(Unido, x="Churn", y="tenure", title="Distribución de 'Tiempo de Contrato' para clientes con y sin evasión")
fig_tenure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Unido.describe(percentiles=None, include=None, exclude=None)
# Out:
#        SeniorCitizen       tenure  Charges.Monthly
# count    7267.000000  7267.000000      7267.000000
# mean        0.162653    32.346498        64.720098
# std         0.369074    24.571773        30.129572
# min         0.000000     0.000000        18.250000
# 25%         0.000000     9.000000        35.425000
# 50%         0.000000    29.000000        70.300000
# 75%         0.000000    55.000000        89.875000
# max         1.000000    72.000000       118.750000

# %% [markdown]
# #📄Informe final

# %% [markdown]
# El metodo de pago que mas evación presenta corresponde al cheque electronico, en relación con los clientes que se dan de baja no existe diferencia considerable enter hombres y mujeres, aun así el mayor porcentaje de clientes se da de baja en los primeros meses del servicio.  Se debe poner principal cuidado y decicación en mantener interesados a este tipo de clientes, a medida que avanza el tiempo será menos probable que den de baja el servicio
